# %% [markdown]
# <a href="https://colab.research.google.com/github/25b073/class01/blob/main/2_%EA%B2%8C%EC%9E%84%EB%A7%8C%EB%93%A4%EA%B8%B0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 첫번째 게임

# %%
import random

# print : 출력하기
# range : 범위
# treasure : 보물
# break : 깨다. 멈추다.
# if : 만약
# else : 그 밖에 다른

# 보물이 들어있는 상자 번호 (1~5 중 하나 무작위)
treasure_box = random.randint(1, 5)

print("🏴‍☠️ 보물 상자 찾기 게임!")
print("1번부터 5번까지 상자 중 하나에 보물이 있어요.\n")

# for 문을 이용해서 상자 하나씩 열어보기
for box_number in range(1, 6):
    print(f"{box_number}번 상자를 열어볼게요...")

    if box_number == treasure_box:
        print("🎉 보물을 찾았어요! 축하합니다!")
        break
    else:
        print("빈 상자였어요 😢\n")

else:
    print("모든 상자를 열었지만 보물을 찾지 못했어요...")

print("\n게임 끝!")
# Out:
# 🏴‍☠️ 보물 상자 찾기 게임!
# 1번부터 5번까지 상자 중 하나에 보물이 있어요.
#
# 1번 상자를 열어볼게요...
# 빈 상자였어요 😢
#
# 2번 상자를 열어볼게요...
# 빈 상자였어요 😢
#
# 3번 상자를 열어볼게요...
# 🎉 보물을 찾았어요! 축하합니다!
#
# 게임 끝!

# %% [markdown]
# # 두번째 게임(내가 직접 하는 게임)

# %%
import random

# except : 예외
# choice : 선택
# attempt : 시도

treasure_box = random.randint(1, 5)

print("🎮 보물 상자 찾기 게임 (사용자 선택 버전)!")
print("1번부터 5번까지 상자 중 하나에 보물이 있어요.")
print("총 3번 기회가 있어요. 숫자를 입력해서 상자를 열어보세요.\n")

for attempt in range(1, 4):
    try:
        choice = int(input(f"[{attempt}/3쇼ㅕㅓㅏ
        ] 열고 싶은 상자 번호를 입력하세요 (1~5): "))

        if choice < 1 or choice > 5:
            print("❗ 1에서 5 사이의 숫자를 입력해주세요.\n")
            continue

        if choice == treasure_box:
            print("🎉 축하합니다! 보물을 찾았어요!")
            break
        else:
            print("😢 빈 상자였어요.\n")
    except ValueError:
        print("❗ 숫자를 입력해주세요.\n")

else:
    print("💥 3번의 기회를 모두 사용했어요. 보물은 찾지 못했네요!")

print("\n게임 끝!")
# Out:
# 🎮 보물 상자 찾기 게임 (사용자 선택 버전)!
# 1번부터 999번까지 상자 중 하나에 보물이 있어요.
# 총 3번 기회가 있어요. 숫자를 입력해서 상자를 열어보세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-c3023a582595> in <cell line: 0>()
#      13 for attempt in range(1, 4):
#      14     try:
# ---> 15         choice = int(input(f"[{attempt}/99999] 열고 싶은 상자 번호를 입력하세요 (1~5): "))
#      16
#      17         if choice < 1 or choice > 5:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # 내가 해킹한 게임
# 게임을 내 마음대로 수정해보기

# %%
import random

# except : 예외
# choice : 선택
# attempt : 시도

treasure_box = random.randint(1, 100)

print("🎮 보물 상자 찾기 게임 (사용자 선택 버전)!")
print("1번부터 100번까지 상자 중 하나에 보물이 있어요.")
print("총 1번 기회가 있어요. 숫자를 입력해서 상자를 열어보세요.\n")

for attempt in range(1, 100):
    try:
        choice = int(input(f"[{attempt}/1] 열고 싶은 상자 번호를 입력하세요 (1~100): "))

        if choice < 1 or choice > 100:
            print("🎉 축하합니다! 보물을 찾았어요!")
            continue

        if choice == treasure_box:
            print("🎉 축하합니다! 보물을 찾았어요!")
            break

    except ValueError:
        print("🎉 축하합니다! 보물을 찾았어요!")

else:
    print("🎉 축하합니다! 보물을 찾았어요!")

print("\n게임 끝!")
# Out:
# 🎮 보물 상자 찾기 게임 (사용자 선택 버전)!
# 1번부터 100번까지 상자 중 하나에 보물이 있어요.
# 총 1번 기회가 있어요. 숫자를 입력해서 상자를 열어보세요.
#
# 🎉 축하합니다! 보물을 찾았어요!
